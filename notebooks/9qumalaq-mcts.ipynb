# %% [markdown]
# ## 🦜 Cloning repo

# %%
#! rm -r togyz-qumalaq-agent

# %%
# !git clone https://github.com/zhus-dika/togyz-qumalaq-agent.git
# Out:
# Cloning into 'togyz-qumalaq-agent'...
# remote: Enumerating objects: 1120, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 1120 (delta 133), reused 150 (delta 67), pack-reused 895 (from 1)
# Receiving objects: 100% (1120/1120), 1.68 GiB | 34.94 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %% [markdown]
# ## 🦉 Install need packages

# %%
# !pip install -r /kaggle/working/togyz-qumalaq-agent/requirements.txt
# Out:
# Collecting absl-py==2.1.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 1))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting asttokens==3.0.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 2))
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting cloudpickle==3.1.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 3))
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting coloredlogs==15.0.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 4))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting contourpy==1.3.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 5))
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: decorator==5.1.1 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: deepdiff==7.0.1 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 8)) (7.0.1)
# Collecting distlib==0.3.9 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 9))
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting executing==2.1.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 10))
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: Farama-Notifications==0.0.4 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 11)) (0.0.4)
# Collecting filelock==3.16.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 12))
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fonttools==4.55.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 13))
#   Downloading fonttools-4.55.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 4.1 MB/s eta 0:00:0000:01
# Collecting fsspec==2024.12.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 14))
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting grpcio==1.69.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 15))
#   Downloading grpcio-1.69.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting gymnasium==0.28.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 16))
#   Downloading gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Collecting h5py==3.12.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 17))
#   Downloading h5py-3.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting humanfriendly==10.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 18))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting ipython==8.31.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 19))
#   Downloading ipython-8.31.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jax-jumpy==1.0.0 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 20)) (1.0.0)
# Collecting jedi==0.19.2 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 21))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.5 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 22))
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting kiwisolver==1.4.8 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 23))
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Collecting llvmlite==0.43.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 24))
#   Downloading llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting Markdown==3.7 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 25))
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting MarkupSafe==3.0.2 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 26))
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting matplotlib==3.10.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 27))
#   Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting matplotlib-inline==0.1.7 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 28))
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 29)) (1.3.0)
# Collecting networkx==3.4.2 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 30))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting numba==0.60.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 31))
#   Downloading numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 32)) (1.26.4)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 33))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 34))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 35))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 36))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 37))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 38))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 39))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 40))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 41))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 42))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 43))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 44))
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: ordered-set==4.1.0 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 45)) (4.1.0)
# Collecting overrides==7.7.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 46))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting packaging==24.2 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 47))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pandas==2.2.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 48))
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.9 MB/s eta 0:00:00
# Collecting parso==0.8.4 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 49))
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting pettingzoo==1.24.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 50))
#   Downloading pettingzoo-1.24.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting pexpect==4.9.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 51))
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pillow==11.1.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 52))
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting platformdirs==4.3.6 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 53))
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting plotly==5.24.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 54))
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting prompt_toolkit==3.0.48 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 55))
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Collecting protobuf==5.29.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 56))
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: ptyprocess==0.7.0 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 57)) (0.7.0)
# Collecting pure_eval==0.2.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 58))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting Pygments==2.19.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 59))
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyparsing==3.2.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 60))
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 61)) (2.9.0.post0)
# Collecting pytz==2024.2 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 62))
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting sensai-utils==1.3.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 63))
#   Downloading sensai_utils-1.3.0-py3-none-any.whl.metadata (599 bytes)
# Collecting setuptools==75.8.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 64))
#   Downloading setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting six==1.17.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 65))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting stack-data==0.6.3 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 66))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting sympy==1.13.1 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 67))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting tenacity==9.0.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 68))
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tensorboard==2.18.0 (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 69))
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /opt/conda/lib/python3.10/site-packages (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 70)) (0.7.2)
# ERROR: Ignored the following versions that require a different python version: 0.36.0 Requires-Python >=3.6,<3.10; 0.37.0 Requires-Python >=3.7,<3.10; 0.52.0 Requires-Python >=3.6,<3.9; 0.52.0rc3 Requires-Python >=3.6,<3.9; 0.53.0 Requires-Python >=3.6,<3.10; 0.53.0rc1.post1 Requires-Python >=3.6,<3.10; 0.53.0rc2 Requires-Python >=3.6,<3.10; 0.53.0rc3 Requires-Python >=3.6,<3.10; 0.53.1 Requires-Python >=3.6,<3.10; 0.54.0 Requires-Python >=3.7,<3.10; 0.54.0rc2 Requires-Python >=3.7,<3.10; 0.54.0rc3 Requires-Python >=3.7,<3.10; 0.54.1 Requires-Python >=3.7,<3.10; 1.0.0 Requires-Python <4.0,>=3.11; 1.1.0 Requires-Python <4.0,>=3.11; 1.10.0 Requires-Python >=3.6, <3.10; 1.11.0 Requires-Python >=3.6, <3.10; 1.11.1 Requires-Python >=3.6, <3.10; 1.11.2 Requires-Python >=3.6, <3.10; 1.12.0 Requires-Python >=3.6, <3.10; 1.13.0 Requires-Python >=3.7, <3.10; 1.13.1 Requires-Python >=3.7, <3.10; 1.4.0 Requires-Python >=3.6, <3.9; 1.4.1 Requires-Python >=3.6, <3.9; 1.4.2 Requires-Python >=3.6, <3.9; 1.5.0 Requires-Python >=3.6, <3.10; 1.5.1 Requires-Python >=3.6, <3.10; 1.5.2 Requires-Python >=3.6, <3.10; 1.6.0 Requires-Python >=3.6, <3.10; 1.6.1 Requires-Python >=3.6, <3.10; 1.7.0 Requires-Python >=3.6, <3.10; 1.8.0 Requires-Python >=3.6, <3.10; 1.8.1 Requires-Python >=3.6, <3.10; 1.8.2 Requires-Python >=3.6, <3.10; 1.9.0 Requires-Python >=3.6, <3.10
# ERROR: Could not find a version that satisfies the requirement tianshou==1.1.0 (from versions: 0.2.0, 0.2.0.post1, 0.2.0.post2, 0.2.1, 0.2.2, 0.2.3, 0.2.4, 0.2.4.post1, 0.2.5, 0.2.6, 0.2.7, 0.3.0rc0, 0.3.0, 0.3.0.post1, 0.3.1, 0.3.2, 0.4.0, 0.4.1, 0.4.2, 0.4.3, 0.4.4, 0.4.5, 0.4.6, 0.4.6.post1, 0.4.7, 0.4.8, 0.4.9, 0.4.9.post1, 0.4.10, 0.4.11, 0.5.0, 0.5.1)
# ERROR: No matching distribution found for tianshou==1.1.0

# %%
# !pip install tianshou coloredlogs
# Out:
# Collecting tianshou
#   Downloading tianshou-0.5.1-py3-none-any.whl.metadata (34 kB)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: gymnasium>=0.26.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (0.29.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from tianshou) (4.66.4)
# Requirement already satisfied: numpy>1.16.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (1.26.4)
# Requirement already satisfied: tensorboard>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (2.15.1)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (2.1.2+cpu)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (0.58.1)
# Requirement already satisfied: h5py>=2.10.0 in /opt/conda/lib/python3.10/site-packages (from tianshou) (3.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tianshou) (21.3)
# Requirement already satisfied: pettingzoo>=1.22 in /opt/conda/lib/python3.10/site-packages (from tianshou) (1.24.0)
# Collecting humanfriendly>=9.1 (from coloredlogs)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->tianshou) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->tianshou) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->tianshou) (0.0.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->tianshou) (0.41.1)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (3.5.2)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (69.0.3)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard>=2.5.0->tianshou) (3.0.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->tianshou) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->tianshou) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->tianshou) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->tianshou) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->tianshou) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tianshou) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->tianshou) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->tianshou) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->tianshou) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.5.0->tianshou) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->tianshou) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->tianshou) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->tianshou) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->tianshou) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.5.0->tianshou) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->tianshou) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.5.0->tianshou) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.5.0->tianshou) (3.2.2)
# Downloading tianshou-0.5.1-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 5.6 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, tianshou
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 tianshou-0.5.1

# %% [markdown]
# ## 🦚 Load previous model

# %%
# !mkdir trained_models
# !mkdir trained_models/mcts

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
import gdown 
import os

url = "https://drive.google.com/uc?id=1m18doVUeQbfOPjVg-mO_5kSi2m0BsCHJ"
output = os.path.join('trained_models','mcts','checkpoint_0.pth.tar')
gdown.download(url, output, quiet=False)
url = "https://drive.google.com/uc?id=1mFLUhe7abgP1EPsv3lH49M6AlS7YkMA2"
output = os.path.join('trained_models','mcts','checkpoint_0.pth.tar.examples')
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1m18doVUeQbfOPjVg-mO_5kSi2m0BsCHJ
# From (redirected): https://drive.google.com/uc?id=1m18doVUeQbfOPjVg-mO_5kSi2m0BsCHJ&confirm=t&uuid=9b0b7f2a-7d79-4264-abab-672a60485526
# To: /kaggle/working/trained_models/mcts/checkpoint_0.pth.tar
# 100%|██████████| 2.02G/2.02G [00:19<00:00, 104MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1mFLUhe7abgP1EPsv3lH49M6AlS7YkMA2
# From (redirected): https://drive.google.com/uc?id=1mFLUhe7abgP1EPsv3lH49M6AlS7YkMA2&confirm=t&uuid=feac4bbc-35b3-4cf7-b0f3-cdbe32bed1b4
# To: /kaggle/working/trained_models/mcts/checkpoint_0.pth.tar.examples
# 100%|██████████| 1.18G/1.18G [00:08<00:00, 142MB/s]
# 'trained_models/mcts/checkpoint_0.pth.tar.examples'

# %% [markdown]
# ## 🐝 Running script

# %%
# !python /kaggle/working/togyz-qumalaq-agent/model_based_approach/main.py
# Out:
# 2025-01-24 14:57:32.136096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 14:57:32.136300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 14:57:32.532753: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-24 14:57:53 24b055b91bab __main__[103] INFO Loading TogyzQumalaqGame...
# 2025-01-24 14:57:53 24b055b91bab __main__[103] INFO Loading NNetWrapper...
# 2025-01-24 14:58:01 24b055b91bab __main__[103] INFO Loading checkpoint "./trained_models/mcts/checkpoint_0.pth.tar"...
# 2025-01-24 14:58:05 24b055b91bab __main__[103] INFO Loading the Coach...
# 2025-01-24 14:58:11 24b055b91bab __main__[103] INFO Loading 'trainExamples' from file...
# 2025-01-24 14:58:11 24b055b91bab Coach[103] INFO File with trainExamples found. Loading it...
# 2025-01-24 14:58:14 24b055b91bab Coach[103] INFO Loading done!
# 2025-01-24 14:58:14 24b055b91bab __main__[103] INFO Starting the learning process 🎉
# 2025-01-24 14:58:14 24b055b91bab Coach[103] INFO Starting Iter #1 ...
# Checkpoint Directory exists!
# EPOCH ::: 1
# Training Net:   1%| | 12/1412 [09:01<16:45:48, 43.11s/it, Loss_pi=1.23e+00, Loss
