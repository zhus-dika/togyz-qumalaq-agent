# %% [markdown]
# ## 🦜 Cloning repo

# %%
#! rm -r togyz-qumalaq-agent

# %%
# !git clone https://github.com/zhus-dika/togyz-qumalaq-agent.git
# Out:
# Cloning into 'togyz-qumalaq-agent'...
# remote: Enumerating objects: 1213, done.
# remote: Counting objects: 100% (318/318), done.
# remote: Compressing objects: 100% (217/217), done.
# remote: Total 1213 (delta 201), reused 202 (delta 95), pack-reused 895 (from 1)
# Receiving objects: 100% (1213/1213), 1.68 GiB | 35.70 MiB/s, done.
# Resolving deltas: 100% (329/329), done.

# %%
# !pip install -r /kaggle/working/togyz-qumalaq-agent/requirements.txt
# Out:
# Processing /C:/b/abs_98xvdek9qa/croot/aext-assistant_1734644152369/work (from -r /kaggle/working/togyz-qumalaq-agent/requirements.txt (line 2))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/C:/b/abs_98xvdek9qa/croot/aext-assistant_1734644152369/work'

# %%
! pip install tianshou coloredlogs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 🦚 Download files

# %%
! pip install gdown

# %%
# !mkdir trained_models
# !mkdir trained_models/mcts

# %%
# import gdown
# import os
# url = "https://drive.google.com/uc?id=1mxTG6SQnw3mecsHUXwlxFVTk2H7cZqfw"
# output = os.path.join('trained_models','mcts','checkpoint_0.pth.tar')
# gdown.download(url, output, quiet=False)

# url = "https://drive.google.com/uc?id=1MLLwMijVKD_Q1rE114RixX5xi2SbfC-b"
# output = os.path.join('trained_models','mcts','checkpoint_0.pth.tar.examples')
# gdown.download(url, output, quiet=False)

# %% [markdown]
# ## 🐝 Running script

# %%
#!python /kaggle/working/togyz-qumalaq-agent/model_based_approach/pit.py

# %%
# !python /kaggle/working/togyz-qumalaq-agent/model_based_approach/main.py
# Out:
# 2025-03-04 04:23:48.884843: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-04 04:23:48.885002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-04 04:23:49.026119: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 04:23:59 277d34afac8a __main__[107] INFO Loading TogyzQumalaqGame...
# 2025-03-04 04:23:59 277d34afac8a __main__[107] INFO Loading NNetWrapper...
# 2025-03-04 04:24:00 277d34afac8a __main__[107] WARNING Not loading a checkpoint!
# 2025-03-04 04:24:00 277d34afac8a __main__[107] INFO Loading the Coach...
# ...
